# %% [markdown]
# <a href="https://colab.research.google.com/github/dopa1593/chess-model/blob/main/code/1%20try/20260916_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://dopa1593: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@github.com/dopa1593/chess-model.git
# Out:
# Cloning into 'chess-model'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 40 (delta 5), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 12.94 KiB | 245.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd chess-model
# Out:
# /content/chess-model

# %%
# !pwd
# Out:
# /content/chess-model

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !mv /content/drive/MyDrive/Colab Notebooks/create_001.ipynb code/
# Out:
# mv: cannot stat '/content/drive/MyDrive/ColabNotebooks/create_001.ipynb': No such file or directory

# %%
!
# Out:
# /content/chess-model

# %%
# !ls
# Out:
# code  README.md

# %%
# !ls code
# Out:
# README

# %%
# !git config --global user.name "dopa1593"
# !git config --global user.email "a01083289436@gmail.com"

# %%
# !git clone https://github.com/dopa1593/chess-model.git
# Out:
# Cloning into 'chess-model'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote set-url origin https://dopa1593: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@github.com/dopa1593/chess-model.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
    # %cd /content/chess-model
# Out:
# [Errno 2] No such file or directory: '/content/chess-model'
# /content

# %%
# !ls /content
# Out:
# chess-model  drive  sample_data

# %%
# !ls /content/chess-model
# Out:
# code  README.md

# %%
# !find /content -name "*.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/pdf_추출(before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/python-basics(before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/python-data-types(before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/pandas-basics (before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/python-if-for-while(before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/for-quiz (before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/vis_seaborn_basic(before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/vis-CCTV(before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/classification (before).ipynb
# /content/drive/MyDrive/Colab Notebooks/kbi/2404실습자료/코드/decision-tree (before).ipynb
# ...
