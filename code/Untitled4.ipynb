# %% [markdown]
# <a href="https://colab.research.google.com/github/dopa1593/chess-model/blob/main/code/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !dir
# Out:
# sample_data
